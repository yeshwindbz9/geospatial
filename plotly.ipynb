# %%
import pandas as pd
import plotly.express as px

# %%
data = pd.read_csv("data/SW_Crimes.csv")
data.head()
# Out:
#                                             Crime ID    Month  \
# 0                                                NaN  2019-06
# 1                                                NaN  2019-06
# 2                                                NaN  2019-06
# 3  9c6776af44dcf2a47c519b6a12d48252824f70c4b305f1...  2019-06
# 4  a2357cab3578d2051e56e474cc091a4d66a96b14bd352c...  2019-06
#
#           Reported by        Falls within       Lon        Lat  \
# 0  South Wales Police  South Wales Police -3.649808  51.638618
# 1  South Wales Police  South Wales Police -3.658223  51.639129
# 2  South Wales Police  South Wales Police -3.649808  51.638618
# 3  South Wales Police  South Wales Police -3.658828  51.634723
# 4  South Wales Police  South Wales Police -3.657789  51.638334
#
#                        Location  LSOA code      LSOA name  \
# 0       On or near North Street  W01000991  Bridgend 001A
# 1  On or near Hartshorn Terrace  W01000991  Bridgend 001A
# ...

# %%
px.set_mapbox_access_token("pk.eyJ1IjoiYWFuZ2VzaCIsImEiOiJja3ZkdnYwcXkweW9mMnhvODJ5Zjhtczg2In0.qd7cCEWbl1qBkrDpnteMGQ")
fig = px.scatter_mapbox(data, lat="Lat", lon="Lon", size="Total crime",
                  color_continuous_scale=px.colors.cyclical.IceFire, size_max=20,zoom=12)
fig.show()

# %%
px.set_mapbox_access_token("pk.eyJ1IjoiYWFuZ2VzaCIsImEiOiJja3ZkdnYwcXkweW9mMnhvODJ5Zjhtczg2In0.qd7cCEWbl1qBkrDpnteMGQ")
fig = px.scatter_mapbox(data, lat="Lat", lon="Lon",color="Crime type", size="Total crime",
                  color_continuous_scale=px.colors.cyclical.IceFire, size_max=20,zoom=12)
fig.show()
